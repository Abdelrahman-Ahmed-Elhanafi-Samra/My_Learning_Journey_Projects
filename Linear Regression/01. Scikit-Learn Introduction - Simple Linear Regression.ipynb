# %% [markdown]
# <img src="./files/Simple Linear Regression with Python1.png"
#      alt="Simple Linear Regression with Python"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# ____________________________________________________________________________________________________
# # <center><span style="color:Purple">Hello this is, *Simple Linear Regression with Python*</span>. 🤖💻
# ____________________________________________________________________________________________________

# %% [markdown]
# ## Setting Up the Working Environment 🛠️

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Importing Datasets 📖
#
# ```python
# from sklearn import datasets
# ```

# %%
from sklearn import datasets

# %% [markdown]
# ## Checking the content of datasets 🔎

# %%
print([data for data in dir(datasets) if '_' and '__' not in data])
# Out:
# ['_base', '_california_housing', '_covtype', '_kddcup99', '_lfw', '_olivetti_faces', '_openml', '_rcv1', '_samples_generator', '_species_distributions', '_svmlight_format_fast', '_svmlight_format_io', '_twenty_newsgroups', 'clear_data_home', 'dump_svmlight_file', 'fetch_20newsgroups', 'fetch_20newsgroups_vectorized', 'fetch_california_housing', 'fetch_covtype', 'fetch_kddcup99', 'fetch_lfw_pairs', 'fetch_lfw_people', 'fetch_olivetti_faces', 'fetch_openml', 'fetch_rcv1', 'fetch_species_distributions', 'get_data_home', 'load_boston', 'load_breast_cancer', 'load_diabetes', 'load_digits', 'load_files', 'load_iris', 'load_linnerud', 'load_sample_image', 'load_sample_images', 'load_svmlight_file', 'load_svmlight_files', 'load_wine', 'make_biclusters', 'make_blobs', 'make_checkerboard', 'make_circles', 'make_classification', 'make_friedman1', 'make_friedman2', 'make_friedman3', 'make_gaussian_quantiles', 'make_hastie_10_2', 'make_low_rank_matrix', 'make_moons', 'make_multilabel_classificati
# ...

# %% [markdown]
# ## Scikit-Learn Data Type ✅

# %%
import warnings
warnings.filterwarnings('ignore')
# ---------------------------------

boston = datasets.load_boston()

# %%
type(boston)  # Bunch which is similar to a dict
# Out:
# sklearn.utils.Bunch

# %%
dir(boston)
# Out:
# ['DESCR', 'data', 'data_module', 'feature_names', 'filename', 'target']

# %%
print(boston.keys())
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename', 'data_module'])

# %% [markdown]
# ## Dataset Description

# %%
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# ## Feature Names

# %%
boston.feature_names
# Out:
# array(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD',
#        'TAX', 'PTRATIO', 'B', 'LSTAT'], dtype='<U7')

# %% [markdown]
# ## Data

# %%
boston.data
# Out:
# array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#         4.9800e+00],
#        [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#         9.1400e+00],
#        [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#         4.0300e+00],
#        ...,
#        [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         5.6400e+00],
#        [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#         6.4800e+00],
#        [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#         7.8800e+00]])

# %%
boston.data.shape
# Out:
# (506, 13)

# %% [markdown]
# ## The target Variable

# %%
boston.target
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
boston.target.shape
# Out:
# (506,)

# %%
boston.target[:10] #the first 10 values
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9])

# %%
boston.target[-10:] #the last 10 values
# Out:
# array([19.7, 18.3, 21.2, 17.5, 16.8, 22.4, 20.6, 23.9, 22. , 11.9])

# %% [markdown]
# ## Setting the Data for Building Models

# %%
X = boston.data
y = boston.target
bost_df = pd.DataFrame(X, columns = boston.feature_names)

# %%
bost_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
bost_df.tail(10)
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 496  0.28960  0.0   9.69   0.0  0.585  5.390  72.9  2.7986  6.0  391.0
# 497  0.26838  0.0   9.69   0.0  0.585  5.794  70.6  2.8927  6.0  391.0
# 498  0.23912  0.0   9.69   0.0  0.585  6.019  65.3  2.4091  6.0  391.0
# 499  0.17783  0.0   9.69   0.0  0.585  5.569  73.5  2.3999  6.0  391.0
# 500  0.22438  0.0   9.69   0.0  0.585  6.027  79.7  2.4982  6.0  391.0
# 501  0.06263  0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527  0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076  0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959  0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741  0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT
# 496     19.2  396.90  21.14
# 497     19.2  396.90  14.10
# 498     19.2  396.90  12.92
# 499     19.2  395.77  15.10
# 500     19.2  396.90  14.33
# ...

# %% [markdown]
# Or we can do it in one step using this syntax:
# ```python
# datasets.load_boston(return_X_y=True)
# ```

# %%
bost_df['Price'] = y

# %%
bost_df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  Price
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
#bost_df.to_csv('housing.cvs')

# %% [markdown]
# ## Exploratory Data Analysis 📝📊

# %%
bost_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
bost_df.describe().T
# Out:
#          count        mean         std        min         25%        50%  \
# CRIM     506.0    3.613524    8.601545    0.00632    0.082045    0.25651
# ZN       506.0   11.363636   23.322453    0.00000    0.000000    0.00000
# INDUS    506.0   11.136779    6.860353    0.46000    5.190000    9.69000
# CHAS     506.0    0.069170    0.253994    0.00000    0.000000    0.00000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.53800
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.20850
# AGE      506.0   68.574901   28.148861    2.90000   45.025000   77.50000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.20745
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.00000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.00000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.05000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.44000
# ...

# %% [markdown]
# ## Visualization of the target variable

# %%
# setting the figure size
sns.set(rc={'figure.figsize':(12,8)})

# %%
# plot the histogram
plt.hist(boston.target, bins = 50, color = '#88c999')

# label the axes
plt.xlabel('Price in $1000s')
plt.ylabel('Number of houses')
# Out:
# Text(0, 0.5, 'Number of houses')

# %% [markdown]
# ## Feature Selection 🎯

# %%
# Plotting the heatmap
sns.heatmap(bost_df.corr(), square=True, cmap='RdYlGn')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Plotting highley Correlated Features with the Target 📈

# %%
plt.scatter(bost_df['RM'], bost_df['Price'])
plt.xlabel('Number of room')
plt.ylabel('The Price in house $1000s')
plt.title('Price Vs. Average Number of Rooms')
# Out:
# Text(0.5, 1.0, 'Price Vs. Average Number of Rooms')

# %%
sns.lmplot(x = 'RM', y = 'Price', data = bost_df)

# %% [markdown]
# ## Plotting lowerly Correlated Features with the Target 📈

# %%
plt.scatter(bost_df['LSTAT'], bost_df['Price'], color = 'orange')
plt.xlabel('Lower status of the population')
plt.ylabel('The Price in house $1000s')
plt.title('Price Vs. Average Status of the population')
# Out:
# Text(0.5, 1.0, 'Price Vs. Average Status of the population')

# %%
sns.lmplot(x = 'LSTAT', y = 'Price', data = bost_df)

# %% [markdown]
# ## Simple Linear Regression with SK-Learn 🧪

# %%
# Import linear model
from sklearn import linear_model

# %%
# Instantiation/create a LinearRegression object
lm_reg = linear_model.LinearRegression()

# %%
type(lm_reg)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
X = bost_df['RM']
y = bost_df['Price']

# %%
# Print the dimensions of X and y before reshaping
print('Dimensions of X before reshaping: ', X.shape)
print('Dimensions of y before reshaping: ', y.shape)
# Out:
# Dimensions of X before reshaping:  (506,)
# Dimensions of y before reshaping:  (506,)

# %%
# Reshape X and y
X_reshaped = np.array(X).reshape(-1, 1)
y_reshaped = np.array(y).reshape(-1, 1)

# %%
print('Dimensions of X after reshaping: ', X_reshaped.shape)
print('Dimensions of y after reshaping: ', y_reshaped.shape)
# Out:
# Dimensions of X after reshaping:  (506, 1)
# Dimensions of y after reshaping:  (506, 1)

# %% [markdown]
# ## Fitting Linear Regression

# %%
# Fit linear model
lm_reg.fit(X_reshaped, y_reshaped)
# Out:
# LinearRegression()

# %% [markdown]
# ## Check the lm object ☑️

# %%
print([attr for attr in dir(lm_reg) if '_' and '__' not in attr])
# Out:
# ['_abc_impl', '_check_feature_names', '_check_n_features', '_decision_function', '_estimator_type', '_get_param_names', '_get_tags', '_more_tags', '_preprocess_data', '_repr_html_', '_repr_html_inner', '_repr_mimebundle_', '_residues', '_set_intercept', '_validate_data', 'coef_', 'copy_X', 'fit', 'fit_intercept', 'get_params', 'intercept_', 'n_features_in_', 'n_jobs', 'normalize', 'positive', 'predict', 'rank_', 'score', 'set_params', 'singular_']

# %% [markdown]
# ## Check the Intercept and Coefficients ☑️

# %%
# Intercept
print('The intercept of simple linear regression is ', lm_reg.intercept_)
# Out:
# The intercept of simple linear regression is  [-34.67062078]

# %%
# Coefficients
print('The coefficients of simple linear regression is ', lm_reg.coef_)
# Out:
# The coefficients of simple linear regression is  [[9.10210898]]

# %% [markdown]
# ## Saving the results into a table 💾

# %%
inter_coef_df = pd.DataFrame({'Intercept' : lm_reg.intercept_ ,
                              'Coefficient' : lm_reg.coef_.flatten()})
inter_coef_df
# Out:
#    Intercept  Coefficient
# 0 -34.670621     9.102109

# %% [markdown]
# ## The Goodness-of-Fit 🥇

# %%
print("The R^2 of model is: {:0.3f}".format(lm_reg.score(X_reshaped, y_reshaped)))
# Out:
# The R^2 of model is: 0.484

# %% [markdown]
# ## Prediction 🏆
#
#
#
#  - Syntax:
# ```python
#    y_pred = lm_reg.predict(new_data)
# ```

# %%
y_pred = lm_reg.predict(X_reshaped) # I using the same data for educational purposes only

# %% [markdown]
# ## Plotting The Results 📊📝

# %%
plt.scatter(X, y, color = 'black', alpha = 0.5)
plt.plot(X_reshaped, y_pred, color = 'gold', linewidth = 3)
plt.show()

# %% [markdown]
# __________________________________________________________________
# # <span style="color:Purple">End The Project, *Thank you*</span> 🔚🥀
# __________________________________________________________________
